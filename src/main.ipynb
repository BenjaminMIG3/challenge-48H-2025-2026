# %%
import pandas as pd 
from dotenv import load_dotenv
import os
import asyncio  # Nécessaire pour exécuter les requêtes async
from mistralai import Mistral
import json
import time as t

# %%
# Charger les variables d'environnement
load_dotenv()

# Récupérer la clé API
api_key = os.getenv("MISTRAL_API_KEY")
print(f"Clé API récupérée : {api_key}")

# Vérifier que la clé API est bien définie
if not api_key:
    raise ValueError("La clé API MISTRAL_API_KEY n'est pas définie dans l'environnement.")
# Out:
# Clé API récupérée : HpgdFoHK7j9AcjkEtPjJ5iuffkkEOXSj

# %%
# Initialiser le nouveau client Mistral (asynchrone)
client = Mistral(api_key=api_key)

# %%
def chat_bot(data: pd.DataFrame) -> pd.DataFrame:
    
    cpt = 0

    Sentiment = []
    Urgence = []
    Probleme = []
    Mot =[]
    inconfort =[]
    tipe = []
    Deception =[]
    Satisfaction =[]
    Frustration =[]

    for row in data.iterrows():
        cpt += 1
        t.sleep(2)
        
        response =  client.agents.complete(
            agent_id = "ag:753184c9:20250310:untitled-agent:dd78dfa6",  # Remplace par le bon modèle
            messages = [{"role": "user", "content": row[1]['Messages']}],
            response_format = {"type" :"json_object"}
        )

        # Transformation de la reponse en json
        resp = response.choices[0].message.content.strip()
        response_json = json.loads(resp)

        # Ajout des éléments de réponse à leur tableau respectif
        try:
            Sentiment.append(response_json['Sentiment'])
        except:
            Sentiment.append("")
        try:
            Urgence.append(response_json['Urgence'])
        except:
            Urgence.append("")
        try:
            Probleme.append(response_json['Problèmes'])
        except:
            Probleme.append("")
        try:
            Mot.append(response_json['mot-critique'])
        except:
            Mot.append("")
        try:
            inconfort.append(response_json["Pourcentage d'inconfort"])
        except:
            inconfort.append("")
        try:
            tipe.append(response_json["Type de réclamation"])
        except:
            tipe.append("")
        try:
            Deception.append(response_json['Déception'])
        except:
            Deception.append("")
        try:
            Satisfaction.append(response_json['Satisfaction'])
        except:
            Satisfaction.append("")
        try:
            Frustration.append(response_json['Frustration'])
        except:
            Frustration.append("")

        # print(response_json["Sentiment"])
        # print(response_json["Problèmes"])
        # print(response_json["Urgence"])
        # print(response_json["mot-critique"])
        # print(response_json["Pourcentage d\'inconfort"])
        # print(response_json["Type de réclamation"])
        # print(response_json["Déception"])
        # print(response_json["Satisfaction"])
        # print(response_json["Frustration"])
        print(f"{str(cpt)}/576 : OK")
    
    # Ajout des nouvelles colonnes dans le dataframe
    data['Sentiment'] = Sentiment
    data['Urgence'] = Urgence
    data['Probleme'] = Probleme
    data['mot-critique'] = Mot
    data['incomfort'] = inconfort
    data['type'] = tipe
    data['Deception'] = Deception
    data['Satisfaction'] = Satisfaction
    data['Frustration'] = Frustration

    return data

# %%
df = pd.read_csv('filtered_tweets_engie.csv', sep=';')
print(df.shape) # (576, 5)
df.head(10)
# Out:
# (576, 5)
#             id      screen_name                name  \
# 0  1,72517E+18       gptournier  Guillaume Tournier
# 1  1,72868E+18       jouanetwan      Jouan Etwan 💚💛
# 2  1,73784E+18  vince_thouvenin           thouvenin
# 3  1,74049E+18   BiduleAnatheme     Anathème Bidule
# 4  1,74068E+18  vince_thouvenin           thouvenin
# 5  1,74069E+18         dionombo          Zawarudo 😈
# 6  1,74071E+18        hawaien88           hawaien88
# 7  1,74073E+18        hawaien88           hawaien88
# 8   1,7411E+18    Petit20850206               Petit
# 9   1,7418E+18       Jules_brdn     🇷🇸 Ajde Ana! 🇷🇸
#
#                    created_at  \
# 0  2023-11-16 16:13:18 +01:00
# 1  2023-11-26 08:34:34 +01:00
# 2  2023-12-21 15:27:08 +01:00
# 3  2023-12-28 22:32:58 +01:00
# 4  2023-12-29 11:08:10 +01:00
# 5  2023-12-29 12:13:42 +01:00
# 6  2023-12-29 13:16:46 +01:00
# 7  2023-12-29 15:01:48 +01:00
# 8  2023-12-30 14:55:44 +01:00
# 9  2024-01-01 13:45:32 +01:00
#
#                                            full_text
# 0  @ENGIEpartFR \n6 mois d’attente et tjs aucune ...
# 1  Bonjour @ENGIEpartSAV , l’appli #monpilotageel...
# 2  @ENGIEpartFR mon syndic de copropriété sergic ...
# 3  @ENGIEpartSAV vous envisagez de vous occuper d...
# 4  @ENGIEpartSAV retour de votre technicien "vous...
# 5  @ENGIEpartFR Merci pour l'annulation d'entreti...
# 6  Je m’explique mal où c’est les personnes du ch...
# 7  @ENGIEpartSAV Et c’est si compliqué d’explique...
# 8  @ENGIEpartFR Bonjour, J'ai reçu un courrier de...
# 9  @ENGIEpartSAV urgent !! Une honte mon abonneme...

# %%
df['date'] = pd.to_datetime(df['created_at'], utc=True)
df.head()
# Out:
#             id      screen_name                name  \
# 0  1,72517E+18       gptournier  Guillaume Tournier
# 1  1,72868E+18       jouanetwan      Jouan Etwan 💚💛
# 2  1,73784E+18  vince_thouvenin           thouvenin
# 3  1,74049E+18   BiduleAnatheme     Anathème Bidule
# 4  1,74068E+18  vince_thouvenin           thouvenin
#
#                    created_at  \
# 0  2023-11-16 16:13:18 +01:00
# 1  2023-11-26 08:34:34 +01:00
# 2  2023-12-21 15:27:08 +01:00
# 3  2023-12-28 22:32:58 +01:00
# 4  2023-12-29 11:08:10 +01:00
#
#                                            full_text                      date
# 0  @ENGIEpartFR \n6 mois d’attente et tjs aucune ... 2023-11-16 15:13:18+00:00
# 1  Bonjour @ENGIEpartSAV , l’appli #monpilotageel... 2023-11-26 07:34:34+00:00
# 2  @ENGIEpartFR mon syndic de copropriété sergic ... 2023-12-21 14:27:08+00:00
# 3  @ENGIEpartSAV vous envisagez de vous occuper d... 2023-12-28 21:32:58+00:00
# 4  @ENGIEpartSAV retour de votre technicien "vous... 2023-12-29 10:08:10+00:00

# %%
df.drop(columns=['id', 'screen_name', 'created_at'],axis=1, inplace=True) #le inplace sert a du coup eviter de creer une variable "df", le inplace sert deja a mettre les valeurs dans le tableau 
df.head()
# Out:
#                  name                                          full_text  \
# 0  Guillaume Tournier  @ENGIEpartFR \n6 mois d’attente et tjs aucune ...
# 1      Jouan Etwan 💚💛  Bonjour @ENGIEpartSAV , l’appli #monpilotageel...
# 2           thouvenin  @ENGIEpartFR mon syndic de copropriété sergic ...
# 3     Anathème Bidule  @ENGIEpartSAV vous envisagez de vous occuper d...
# 4           thouvenin  @ENGIEpartSAV retour de votre technicien "vous...
#
#                        date
# 0 2023-11-16 15:13:18+00:00
# 1 2023-11-26 07:34:34+00:00
# 2 2023-12-21 14:27:08+00:00
# 3 2023-12-28 21:32:58+00:00
# 4 2023-12-29 10:08:10+00:00

# %%
df.rename(columns={'name' : "Nom",'full_text' : 'Messages', 'date' : 'Date_de_publication'}, inplace=True )
df.head()
# Out:
#                   Nom                                           Messages  \
# 0  Guillaume Tournier  @ENGIEpartFR \n6 mois d’attente et tjs aucune ...
# 1      Jouan Etwan 💚💛  Bonjour @ENGIEpartSAV , l’appli #monpilotageel...
# 2           thouvenin  @ENGIEpartFR mon syndic de copropriété sergic ...
# 3     Anathème Bidule  @ENGIEpartSAV vous envisagez de vous occuper d...
# 4           thouvenin  @ENGIEpartSAV retour de votre technicien "vous...
#
#         Date_de_publication
# 0 2023-11-16 15:13:18+00:00
# 1 2023-11-26 07:34:34+00:00
# 2 2023-12-21 14:27:08+00:00
# 3 2023-12-28 21:32:58+00:00
# 4 2023-12-29 10:08:10+00:00

# %%
# Nombre de tweets par jour
tweets_per_day = df.groupby(df['Date_de_publication'].dt.date).size()
print("Tweets par jour:\n", tweets_per_day)
# Out:
# Tweets par jour:
#  Date_de_publication
# 2023-11-16    1
# 2023-11-26    1
# 2023-12-21    1
# 2023-12-28    1
# 2023-12-29    4
#              ..
# 2025-02-24    9
# 2025-02-25    3
# 2025-02-26    3
# 2025-03-03    5
# 2025-03-04    1
# Length: 292, dtype: int64

# %%
# Nombre de tweets par semaine
tweets_per_week = df.groupby(df['Date_de_publication'].dt.to_period('W')).size()
print("Tweets par semaine:\n", tweets_per_week)
# Out:
# Tweets par semaine:
#  Date_de_publication
# 2023-11-13/2023-11-19     1
# 2023-11-20/2023-11-26     1
# 2023-12-18/2023-12-24     1
# 2023-12-25/2023-12-31     6
# 2024-01-01/2024-01-07    12
#                          ..
# 2025-02-03/2025-02-09     3
# 2025-02-10/2025-02-16     8
# 2025-02-17/2025-02-23    11
# 2025-02-24/2025-03-02    15
# 2025-03-03/2025-03-09     6
# Freq: W-SUN, Length: 66, dtype: int64
# C:\Users\JENGO\AppData\Local\Temp\ipykernel_15800\1359179801.py:2: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   tweets_per_week = df.groupby(df['Date_de_publication'].dt.to_period('W')).size()

# %%
# Nombre de tweets par mois
tweets_per_month = df.groupby(df['Date_de_publication'].dt.to_period('M')).size()
print("Tweets par mois:\n", tweets_per_month)
# Out:
# Tweets par mois:
#  Date_de_publication
# 2023-11     2
# 2023-12     7
# 2024-01    60
# 2024-02    57
# 2024-03    55
# 2024-04    41
# 2024-05    41
# 2024-06    22
# 2024-07    28
# 2024-08    28
# 2024-09    24
# 2024-10    40
# 2024-11    43
# 2024-12    44
# 2025-01    41
# 2025-02    37
# 2025-03     6
# Freq: M, dtype: int64
# C:\Users\JENGO\AppData\Local\Temp\ipykernel_15800\3563818293.py:2: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   tweets_per_month = df.groupby(df['Date_de_publication'].dt.to_period('M')).size()

# %%
# Fréquence des mentions des comptes Engie
engie_mentions = df['Messages'].str.contains('@Engie', case=False, na=False).sum()
print("Fréquence des mentions des comptes Engie:", engie_mentions)
# Out:
# Fréquence des mentions des comptes Engie: 573

# %%
# Liste des mots-clés critiques
keywords = ["délai", "panne", "urgence", "scandale"]
keywords_regex = '|'.join(keywords)

# Détection des tweets contenant des mots-clés critiques
critical_tweets = df['Messages'].str.contains(keywords_regex, case=False, na=False).sum()
print("Nombre de tweets contenant des mots-clés critiques:", critical_tweets)
# Out:
# Nombre de tweets contenant des mots-clés critiques: 31

# %%
df = chat_bot(df)
df.to_csv("Cleaned_file.csv", sep=";", encoding='utf-8', index=False, header=True)
print(df.shape)
df.head()
# Temps :
# Out:
# Négatif
# ['Attente prolongée', 'Absence de réponse', 'Relances infructueuses', 'Service client inefficace']
# True
# ['6 mois d’attente', 'aucune réponse', 'multiples relances', 'coincé', 'dommage']
# 80
# Service client
# 85
# 5
# 90
# 1/576 : OK
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 df = chat_bot(df)
#       2 df.to_csv("Cleaned_file.csv", sep=";", encoding='utf-8', index=False, header=True)
#       3 print(df.shape)
#
# Cell In[110], line 19, in chat_bot(data)
#      16 cpt += 1
#      17 t.sleep(2)
# ---> 19 response =  client.agents.complete(
#      20     agent_id = "ag:753184c9:20250310:untitled-agent:dd78dfa6",  # Remplace par le bon modèle
#      21     messages = [{"role": "user", "content": row[1]['Messages']}],
#      22     response_format = {"type" :"json_object"}
#      23 )
#      25 # Transformation de la reponse en json
#      26 resp = response.choices[0].message.content.strip()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mistralai\agents.py:133, in Agents.complete(self, messages, agent_id, max_tokens, stream, stop, random_seed, response_format, tools, tool_choice, presence_penalty, frequency_penalty, n, prediction, retries, server_url, timeout_ms, http_headers)
#     130 if isinstance(retries, utils.RetryConfig):
#     131     retry_config = (retries, ["429", "500", "502", "503", "504"])
# --> 133 http_res = self.do_request(
#     134     hook_ctx=HookContext(
#     135         operation_id="agents_completion_v1_agents_completions_post",
#     136         oauth2_scopes=[],
#     137         security_source=get_security_from_env(
#     138             self.sdk_configuration.security, models.Security
#     139         ),
#     140     ),
#     141     request=req,
#     142     error_status_codes=["422", "4XX", "5XX"],
#     143     retry_config=retry_config,
#     144 )
#     146 data: Any = None
#     147 if utils.match_response(http_res, "200", "application/json"):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mistralai\basesdk.py:273, in BaseSDK.do_request(self, hook_ctx, request, error_status_codes, stream, retry_config)
#     271     http_res = utils.retry(do, utils.Retries(retry_config[0], retry_config[1]))
#     272 else:
# --> 273     http_res = do()
#     275 if not utils.match_status_codes(error_status_codes, http_res.status_code):
#     276     http_res = self.sdk_configuration.get_hooks().after_success(
#     277         AfterSuccessContext(hook_ctx), http_res
#     278     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mistralai\basesdk.py:234, in BaseSDK.do_request.<locals>.do()
#     224     req = self.sdk_configuration.get_hooks().before_request(
#     225         BeforeRequestContext(hook_ctx), request
#     226     )
#     227     logger.debug(
#     228         "Request:\nMethod: %s\nURL: %s\nHeaders: %s\nBody: %s",
#     229         req.method,
#    (...)
#     232         get_body_content(req),
#     233     )
# --> 234     http_res = client.send(req, stream=stream)
#     235 except Exception as e:
#     236     _, e = self.sdk_configuration.get_hooks().after_error(
#     237         AfterErrorContext(hook_ctx), None, e
#     238     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
